# %% [markdown]
# # Imports

# %%
# Get pandas and postgres to work together
import psycopg2 as pg
import pandas as pd
import pandas.io.sql as pd_sql

# Data Vizs
import matplotlib.pyplot as plt
# %matplotlib inline

# There is a bug in matplotlib. You cannot set the rc parameters in the same
# cell that you use the "%matplotlib inline" magic command
plt.style.use('ggplot')
plt.rc('font', size=18)

# Postgres info to connect
connection_args = {
    'host': '3.16.149.40',  # We are connecting to our _local_ version of psql
    'user':'ubuntu',
    'dbname': 'realestate',    # DB that we are connecting to
    'port': 5432          # port we opened on AWS
}

# Magic Python trick!
connection = pg.connect(**connection_args)
from psycopg2.extensions import ISOLATION_LEVEL_AUTOCOMMIT
connection.set_isolation_level(ISOLATION_LEVEL_AUTOCOMMIT)

# %% [markdown]
# # Query to AWS

# %%
query = "SELECT * FROM inventorymetrics;"

inventory_df = pd_sql.read_sql(query, connection)

# %%
OG_inventory_df = inventory_df.copy()

# %% [markdown]
# # Inventory DataFrame Cleaning

# %%
inventory_df = OG_inventory_df.copy()

# %%
# DF Update: update month to datetime

inventory_df['month'] = pd.to_datetime(inventory_df['month'])

# %%
# DF Update: update zipcode to int

inventory_df['zipcode'] = inventory_df['zipcode'].astype(int)

# %%
# DF Updates: remove footnote column

inventory_df = inventory_df.drop(columns = ['footnote'] )

# %%
inventory_df.columns
# Out:
# Index(['month', 'zipcode', 'zipname', 'medianlistingprice',
#        'medianlistingprice_mm', 'medianlistingprice_yy', 'activelistingcount',
#        'activelistingcount_mm', 'activelistingcount_yy', 'daysonmarket',
#        'daysonmarket_mm', 'daysonmarket_yy', 'newlistingcount',
#        'newlistingcount_mm', 'newlistingcount_yy', 'priceincreasecount',
#        'priceincreasecount_mm', 'priceincreasecount_yy', 'pricedecreasecount',
#        'pricedecreasecount_mm', 'pricedecreasecount_yy', 'pendinglistingcount',
#        'pendinglistingcount_mm', 'pendinglistingcount_yy', 'avglistingprice',
#        'avglistingprice_mm', 'avglistingprice_yy', 'totallistingcount',
#        'totallistingcount_mm', 'totallistingcount_yy', 'pendingratio',
#        'pendingratio_mm', 'pendingratio_yy'],
#       dtype='object')

# %%
# DF Updates: separate zipname column into two columns (name, city)

# new data frame with split value columns 
new = inventory_df["zipname"].str.split(",", n = 2, expand = True) 
  
# making separate first name column from new data frame 
inventory_df["City"]= new[0] 
  
# making separate last name column from new data frame 
inventory_df["State"]= new[1]

# %%
# DF Updates: rename zipname column name to city-state

inventory_df = inventory_df.rename(columns={"zipname": "city-state"})

# %%
inventory_df.columns
# Out:
# Index(['month', 'zipcode', 'city-state', 'medianlistingprice',
#        'medianlistingprice_mm', 'medianlistingprice_yy', 'activelistingcount',
#        'activelistingcount_mm', 'activelistingcount_yy', 'daysonmarket',
#        'daysonmarket_mm', 'daysonmarket_yy', 'newlistingcount',
#        'newlistingcount_mm', 'newlistingcount_yy', 'priceincreasecount',
#        'priceincreasecount_mm', 'priceincreasecount_yy', 'pricedecreasecount',
#        'pricedecreasecount_mm', 'pricedecreasecount_yy', 'pendinglistingcount',
#        'pendinglistingcount_mm', 'pendinglistingcount_yy', 'avglistingprice',
#        'avglistingprice_mm', 'avglistingprice_yy', 'totallistingcount',
#        'totallistingcount_mm', 'totallistingcount_yy', 'pendingratio',
#        'pendingratio_mm', 'pendingratio_yy', 'City', 'State'],
#       dtype='object')

# %%
# DF Updates: Fill na values with 0
inventory_df = inventory_df.fillna(0)

# %%
# remove white space in State column
inventory_df['State'] = inventory_df['State'].str.strip()

# %%
# State column names
inventory_df['State'].unique()
# Out:
# array(['MA', 'RI', 'NH', 'VT', 'ME', 'CT', 'NJ', 'MS', 'NY', 'PA', 'VA',
#        'DE', 'DC', 'MD', 'WV', 'NC', 'SC', 'AL', 'TN', 'GA', 'FL', 'KY',
#        'OH', 'IN', 'MI', 'IA', 'WI', 'MN', 'SD', 'ND', 'MT', 'IL', 'MO',
#        'KS', 'NE', 'LA', 'AR', 'OK', 'TX', 'CO', 'WY', 'ID', 'UT', 'AZ',
#        'NM', 'NV', 'CA', 'HI', 'OR', 'WA', 'AK'], dtype=object)

# %%
# add a month column
inventory_df['month_no']= pd.to_datetime(inventory_df['month'], format='%Y:%M:%D').dt.month
inventory_df.head()
# Out:
#        month  zipcode       city-state  medianlistingprice  \
# 0 2019-04-01     1001       Agawam, MA            213700.0
# 1 2019-04-01     1002      Amherst, MA            499050.0
# 2 2019-04-01     1005        Barre, MA            301275.0
# 3 2019-04-01     1007  Belchertown, MA            369950.0
# 4 2019-04-01     1008    Blandford, MA            181950.0
#
#    medianlistingprice_mm  medianlistingprice_yy  activelistingcount  \
# 0                 0.0739                -0.0904                43.5
# 1                 0.0398                 0.1607                70.5
# 2                -0.0024                 0.0000                17.0
# 3                 0.0291                 0.0000                51.5
# 4                -0.1915                -0.2159                 6.5
#
#    activelistingcount_mm  activelistingcount_yy  daysonmarket  ...  \
# 0                -0.0543                -0.2627         49.50  ...
# 1                 0.1190                -0.2079         43.00  ...
# 2                 0.2143                 0.1333         45.75  ...
# 3                 0.0300                -0.3041         47.50  ...
# 4                -0.0714                 0.0833         34.25  ...
#
#    avglistingprice_yy  totallistingcount  totallistingcount_mm  \
# 0             -0.0602               44.5               -0.0532
# 1              0.0733               70.5                0.1190
# 2              0.4213               17.0                0.2143
# 3              0.0738               51.5                0.0300
# 4             -0.2975                8.5                0.0625
#
#    totallistingcount_yy  pendingratio  pendingratio_mm  pendingratio_yy  \
# 0               -0.2583        0.0230           0.0012           0.0060
# 1               -0.2079        0.0000           0.0000           0.0000
# 2                0.1333        0.0000           0.0000           0.0000
# 3               -0.3041        0.0000           0.0000           0.0000
# 4               -0.0556        0.3077           0.1648          -0.1923
#
#           City  State  month_no
# 0       Agawam     MA         4
# 1      Amherst     MA         4
# 2        Barre     MA         4
# 3  Belchertown     MA         4
# 4    Blandford     MA         4
#
# [5 rows x 36 columns]

# %%
# add a year column
inventory_df['year']= pd.to_datetime(inventory_df['month'], format='%Y:%M:%D').dt.year

# %%
# update month column
inventory_df = inventory_df.rename(columns={"month": "entry_date"})

# %%
inventory_df.head()
# Out:
#   entry_date  zipcode       city-state  medianlistingprice  \
# 0 2019-04-01     1001       Agawam, MA            213700.0
# 1 2019-04-01     1002      Amherst, MA            499050.0
# 2 2019-04-01     1005        Barre, MA            301275.0
# 3 2019-04-01     1007  Belchertown, MA            369950.0
# 4 2019-04-01     1008    Blandford, MA            181950.0
#
#    medianlistingprice_mm  medianlistingprice_yy  activelistingcount  \
# 0                 0.0739                -0.0904                43.5
# 1                 0.0398                 0.1607                70.5
# 2                -0.0024                 0.0000                17.0
# 3                 0.0291                 0.0000                51.5
# 4                -0.1915                -0.2159                 6.5
#
#    activelistingcount_mm  activelistingcount_yy  daysonmarket  ...  \
# 0                -0.0543                -0.2627         49.50  ...
# 1                 0.1190                -0.2079         43.00  ...
# 2                 0.2143                 0.1333         45.75  ...
# 3                 0.0300                -0.3041         47.50  ...
# 4                -0.0714                 0.0833         34.25  ...
#
#    totallistingcount  totallistingcount_mm  totallistingcount_yy  \
# 0               44.5               -0.0532               -0.2583
# 1               70.5                0.1190               -0.2079
# 2               17.0                0.2143                0.1333
# 3               51.5                0.0300               -0.3041
# 4                8.5                0.0625               -0.0556
#
#    pendingratio  pendingratio_mm  pendingratio_yy         City  State  \
# 0        0.0230           0.0012           0.0060       Agawam     MA
# 1        0.0000           0.0000           0.0000      Amherst     MA
# 2        0.0000           0.0000           0.0000        Barre     MA
# 3        0.0000           0.0000           0.0000  Belchertown     MA
# 4        0.3077           0.1648          -0.1923    Blandford     MA
#
#    month_no  year
# 0         4  2019
# 1         4  2019
# 2         4  2019
# 3         4  2019
# 4         4  2019
#
# [5 rows x 37 columns]

# %% [markdown]
# # Illinois DataFrame

# %%
# Illinois DataFrame

il_df = inventory_df[inventory_df['State'] == 'IL']
il_df.head()
# Out:
#      entry_date  zipcode             city-state  medianlistingprice  \
# 9887 2019-04-01    60002            Antioch, IL           250000.00
# 9888 2019-04-01    60004  Arlington Heights, IL           349956.25
# 9889 2019-04-01    60005  Arlington Heights, IL           355725.00
# 9890 2019-04-01    60007  Elk Grove Village, IL           299950.00
# 9891 2019-04-01    60008    Rolling Meadows, IL           249950.00
#
#       medianlistingprice_mm  medianlistingprice_yy  activelistingcount  \
# 9887                -0.0198                 0.0038               186.0
# 9888                 0.0000                -0.0669               407.0
# 9889                 0.0047                -0.0489               232.5
# 9890                 0.0166                 0.0909               199.5
# 9891                 0.0869                 0.0870               142.0
#
#       activelistingcount_mm  activelistingcount_yy  daysonmarket  ...  \
# 9887                 0.1481                -0.1878         44.75  ...
# 9888                 0.1274                 0.0970         38.00  ...
# 9889                 0.2109                 0.0764         35.50  ...
# 9890                 0.2547                 0.2627         37.25  ...
# 9891                 0.1545                 0.0290         38.25  ...
#
#       totallistingcount  totallistingcount_mm  totallistingcount_yy  \
# 9887              190.0                0.1446               -0.2149
# 9888              428.5                0.1306                0.0959
# 9889              248.0                0.2039                0.1121
# 9890              205.0                0.2424                0.2349
# 9891              148.5                0.1423                0.0385
#
#       pendingratio  pendingratio_mm  pendingratio_yy               City  \
# 9887        0.0215          -0.0032          -0.0353            Antioch
# 9888        0.0528           0.0030          -0.0011  Arlington Heights
# 9889        0.0667          -0.0063           0.0343  Arlington Heights
# 9890        0.0276          -0.0102          -0.0231  Elk Grove Village
# 9891        0.0458          -0.0111           0.0095    Rolling Meadows
#
#       State  month_no  year
# 9887     IL         4  2019
# 9888     IL         4  2019
# 9889     IL         4  2019
# 9890     IL         4  2019
# 9891     IL         4  2019
#
# [5 rows x 37 columns]

# %%
inventory_df[inventory_df['zipcode'] == 60419]
# Out:
#         entry_date  zipcode  city-state  medianlistingprice  \
elistingcount_mm  activelistingcount_yy  daysonmarket  ...  \
# 10025                  -0.0294                -0.0100         66.00  ...
# 25053                  -0.0699                 0.0200         72.00  ...
# 40082                  -0.0408                 0.0186         87.75  ...
# 55108                  -0.0878                -0.0311         83.25  ...
# 70138                  -0.0481                 0.0503         75.00  ...
# 85166                   0.0450                 0.0942         65.75  ...
# 100193                  0.1118                 0.0500         64.50  ...
# 115222                  0.0592                -0.0449         65.00  ...
# 130254                 -0.0273                -0.1301         63.50  ...
# 145287                  0.0248                -0.1176         66.50  ...
# 160335                 -0.0213                -0.1006         61.75  ...
# 175358                  0.0967                -0.0810         69.25  ...
# 190379                  0.0000                -0.1176         76.00  ...
# 205398                 -0.0712                -0.1354         71.25  ...
# 220426                 -0.0876                -0.0031         77.75  ...
# 235457                 -0.0112                 0.1132         78.75  ...
# 250484                 -0.0083                 0.0948         80.00  ...
# 265512                  0.0028                -0.0055         72.75  ...
# 280541                  0.0112                -0.0055         72.00  ...
# 295579                 -0.0352                -0.1010         65.25  ...
# 310651                 -0.0134                -0.0264         78.50  ...
# 325646                  0.0447                 0.0686         87.00  ...
# 340664                  0.0000                 0.0317         79.00  ...
# 355692                  0.0529                 0.0915         64.50  ...
# 370726                 -0.0202                 0.0592         69.00  ...
# 385758                  0.0710                 0.1158         66.75  ...
# 400783                  0.0189                 0.0221         85.25  ...
# 415814                 -0.0275                 0.0743         94.00  ...
# 430848                 -0.0992                 0.0583         89.25  ...
# 445878                  0.0028                 0.1710         84.75  ...
# ...                        ...                    ...           ...  ...
# 611207                 -0.0032                -0.1095         88.50  ...
# 626234                 -0.0032                -0.0663         81.00  ...
# 641263                  0.0130                -0.0880         73.50  ...
# 656301                  0.0033                -0.1254         76.00  ...
# 671338                  0.1953                -0.2194         73.00  ...
# 686331                  0.0667                 0.0000         62.75  ...
# 701357                  0.0169                 0.0000         67.00  ...
# 716379                 -0.0992                 0.0000         76.00  ...
# 731384                 -0.0903                 0.0000         75.25  ...
# 746342                 -0.1111                 0.0000         81.00  ...
# 761267                  0.0452                -0.1900         76.00  ...
# 776198                 -0.1066                -0.2723         80.50  ...
# 791134                  0.0452                -0.1930         75.00  ...
# 806067                 -0.0264                -0.2420         88.00  ...
# 820983                 -0.0285                -0.1862         80.25  ...
# 835899                 -0.1046                -0.1355         79.00  ...
# 850815                 -0.0273                -0.0025         82.00  ...
# 865730                  0.0605                 0.0413         82.00  ...
# 880660                 -0.0206                -0.0686         88.00  ...
# 895592                 -0.0443                 0.0659         87.25  ...
# 910526                 -0.0146                 0.1501        102.00  ...
# 925459                  0.0300                 0.1771        102.00  ...
# 940390                 -0.0610                 0.0989         94.75  ...
# 955320                 -0.0093                 0.0923         87.00  ...
# 970253                 -0.0183                 0.0591         84.50  ...
# 985185                  0.0453                 0.0657         81.00  ...
# 1000119                 0.0320                -0.0970         83.00  ...
# 1015054                 0.0331                -0.1577         85.00  ...
# 1029988                 0.0155                -0.1846         92.50  ...
# 1044917                -0.0515                -0.1400         96.50  ...
#
#          totallistingcount  totallistingcount_mm  totallistingcount_yy  \
# 10025                181.5                0.0028               -0.0082
# 25053                181.0               -0.0398               -0.0398
# 40082                188.5               -0.0456               -0.0284
# 25417                -0.0217                 0.0596               125.0
# 25418                 0.1265                 0.1294                27.0
# 25419                 0.0657                 0.0964                13.0
# 25420                -0.0075                -0.0320               126.0
# 25421                -0.0610                -0.1192               107.0
# 25422                 0.0438                 0.1819               164.0
# 25423                 0.0113                -0.1307                26.0
# 25424                -0.0072                 0.0446                87.0
# 25425                 0.2721                 0.1428                28.0
# 25426                 0.0134                -0.0009                92.0
# 25427                 0.0500                -0.0065               118.0
# 25428                 0.0715                 0.0000                45.0
# 25429                 0.0000                -0.0335                33.0
# 25430                 0.1036                -0.0947               137.0
# 25431                 0.0233                -0.0205                66.0
# 25432                 0.0007                -0.0387                83.0
# 25433                 0.0000                -0.0897               156.0
# 25434                 0.0282                -0.2660                43.0
# 25435                 0.0014                -0.1521                69.0
# 25436                 0.0000                -0.0249                23.0
# 25437                -0.0589                 0.0000                30.0
# 25438                -0.0198                 0.0000                32.0
# 25439                 0.0337                -0.0428               102.0
# 25440                 0.0476                -0.1032               115.0
# 25441                 0.0582                 0.0000                30.0
# 25442                 0.0329                 0.1072               185.0
# 25443                 0.0313                 0.0313                90.0
# 25444                 0.0000                -0.1045               126.0
# 25445                 0.0759                 0.0000                18.0
#
#        activelistingcount_mm  activelistingcount_yy  daysonmarket  ...  \
# 9887                  0.1481                -0.1878         44.75  ...
# 9888                  0.1274                 0.0970         38.00  ...
# 9889                  0.2109                 0.0764         35.50  ...
# 9890                  0.2547                 0.2627         37.25  ...
# 9891                  0.1545                 0.0290         38.25  ...
# 9892                  0.0844                 0.0447         70.00  ...
# 9893                  0.1528                 0.2327         58.25  ...
# 9894                  0.0579                 0.1292         40.50  ...
# 9895                  0.1691                 0.0220         37.00  ...
# 9896                  0.0872                 0.0459         52.75  ...
# 9897                  0.1838                -0.0756         36.00  ...
# 9898                  0.1753                -0.0372         34.25  ...
# 9899                  0.3042                 0.3151         41.00  ...
# 9900                  0.1000                -0.2143         36.00  ...
# 9901                  0.0089                -0.1567         60.00  ...
# 9902                  0.0736                 0.2185         47.25  ...
# 9903                  0.0650                 0.2241         47.25  ...
# 9904                  0.1600                 0.1877         44.25  ...
# 9905                  0.1189                -0.1855         40.50  ...
# 9906                  0.1250                -0.1643         48.75  ...
# 9907                 -0.1250                -0.2632         54.50  ...
# 9908                  0.1320                -0.0671         53.00  ...
# 9909                  0.2193                 0.2636         42.00  ...
# 9910                  0.0246                 0.2019         59.50  ...
# 9911                  0.2326                -0.0185         55.00  ...
# 9912                  0.2008                 0.2739         59.00  ...
# 9913                  0.1099                 0.0306         72.00  ...
# 9914                  0.0849                -0.1075         41.50  ...
# 9915                  0.1401                 0.0644         45.50  ...
# 9916                  0.1115                 0.0752         46.50  ...
# ...                      ...                    ...           ...  ...
# 25416                 0.0429                -0.1237        103.00  ...
# 25417                 0.0373                 0.1468        152.00  ...
# 25418                 0.0000                -0.1692        162.50  ...
# 25419                 0.0000                -0.3500        110.00  ...
# 25420                -0.0195                -0.0118         75.00  ...
# 25421                -0.0776                -0.0273         86.00  ...
# 25422                 0.0155                -0.1230         81.00  ...
# 25423                 0.0400                 0.4054         86.00  ...
# 25424                 0.0741                -0.0842         66.00  ...
# 25425                -0.0667                 0.0370         65.00  ...
# 25426                 0.1220                -0.0160         81.00  ...
# 25427                 0.0351                 0.2165        154.00  ...
# 25428                -0.1346                -0.0722        137.00  ...
# 25429                 0.1579                 0.0313        113.00  ...
# 25430                -0.0036                -0.1464        123.50  ...
# 25431                -0.0959                -0.0149        140.50  ...
# 25432                 0.1690                 0.1857        103.00  ...
# 25433                 0.0163                -0.1236        145.00  ...
# 25434                -0.0444                 0.1316        147.00  ...
# 25435                -0.0738                 0.0615        117.50  ...
# 25436                -0.1321                -0.3235        160.00  ...
# 25437                 0.2000                -0.1781        134.00  ...
# 25438                 0.1034                 0.0000        131.00  ...
# 25439                -0.0467                -0.1207        140.00  ...
# 25440                -0.0213                -0.0171        123.00  ...
# 25441                 0.0000                -0.0769        110.00  ...
# 25442                 0.0082                -0.1723        110.00  ...
# 25443                -0.0426                 0.0843        135.00  ...
# 25444                 0.0080                 0.1053        158.00  ...
# 25445                -0.0270                 0.2414        110.50  ...
#
#        totallistingcount  totallistingcount_mm  totallistingcount_yy  \
# 9887               190.0                0.1446               -0.2149
# 9888               428.5                0.1306                0.0959
# 9889               248.0                0.2039                0.1121
# 9890               205.0                0.2424                0.2349
# 9891               148.5                0.1423                0.0385
# 9892               790.5                0.0770                0.0415
# 9893               139.5                0.1625                0.3160
# 9894               210.0                0.0769                0.1351
# 9895               339.5                0.1707                0.0226
# 9896               351.5                0.1019                0.0556
# 9897               323.0                0.1875               -0.0528
# 9898                96.0                0.1707               -0.0495
# 9899               193.5                0.2815                0.2325
# 9900                35.0                0.0938               -0.2045
# 9901               121.0                0.0254               -0.1357
# 9902               441.0                0.0889                0.2115
# 9903               116.0                0.1154                0.2473
# 9904               364.5                0.1535                0.2030
# 9905               242.5                0.1279               -0.1667
# 9906                61.0                0.1296               -0.1867
# 9907                14.5               -0.0938               -0.2368
# 9908               431.0                0.1432               -0.0651
# 9909                73.5                0.2250                0.2895
# 9910                64.0                0.0159                0.2308
# 9911                53.0                0.2326               -0.0862
# 9912               152.5                0.2103                0.2815
# 9913               429.0                0.1085                0.0362
# 9914               250.5                0.0751               -0.1022
# 9915               554.0                0.1237                0.0613
# 9916               347.5                0.1282                0.0962
# ...                  ...                   ...                   ...
# 25416               98.0                0.0652               -0.0345
# 25417              154.0                0.0233                0.0732
# 25418               29.0                0.0545               -0.1343
# 25419               16.0                0.1034               -0.3962
# 25420              145.0                0.0469                0.0584
# 25421              122.0               -0.0279                0.0252
# 25422              185.0                0.0452               -0.1127
# 25423               29.0               -0.0169                0.3488
# 25424               97.0                0.0838               -0.0443
# 25425               32.0               -0.0154                0.0000
# 25426               96.0                0.1034               -0.0495
# 25427              121.0                0.0168                0.2161
# 25428               48.0               -0.1028               -0.0103
# 25429               37.0                0.1385                0.0423
# 25430              145.0                0.0211               -0.1212
# 25431               69.0               -0.1039                0.0147
# 25432               88.0                0.1282                0.1656
# 25433              161.0                0.0321               -0.1080
# 25432        0.0602          -0.0384          -0.0183     West Frankfort
# 25433        0.0321           0.0158           0.0180         Carbondale
# 25434        0.0000           0.0000          -0.0263               Anna
# 25435        0.0435           0.0032          -0.0027        Carterville
# 25436        0.0000           0.0000           0.0000      Creal Springs
# 25437        0.0000          -0.1000          -0.0274           Eldorado
# 25438        0.0625           0.0280           0.0208          Goreville
# 25439        0.0392          -0.0075           0.0177         Harrisburg
# 25440        0.0261          -0.0377          -0.0124             Herrin
# 25441        0.1000           0.0500           0.0077      Johnston City
# 25442        0.0270           0.0161          -0.0021             Marion
# 25443        0.0111          -0.0048          -0.0130         Metropolis
# 25444        0.0079          -0.0241          -0.0272        Murphysboro
# 25445        0.1111           0.0030           0.0077             Vienna
#
#        State  month_no  year
# 9887      IL         4  2019
# 9888      IL         4  2019
# 9889      IL         4  2019
# 9890      IL         4  2019
# 9891      IL         4  2019
# 9892      IL         4  2019
# 9893      IL         4  2019
# 9894      IL         4  2019
# 9895      IL         4  2019
# 9896      IL         4  2019
# 9897      IL         4  2019
# 9898      IL         4  2019
# 9899      IL         4  2019
# 9900      IL         4  2019
# 9901      IL         4  2019
# 9902      IL         4  2019
# 9903      IL         4  2019
# 9904      IL         4  2019
# 9905      IL         4  2019
# 9906      IL         4  2019
# 9907      IL         4  2019
# 9908      IL         4  2019
# 9909      IL         4  2019
# 9910      IL         4  2019
# 9911      IL         4  2019
# 9912      IL         4  2019
# 9913      IL         4  2019
# 9914      IL         4  2019
# 9915      IL         4  2019
# 9916      IL         4  2019
# ...      ...       ...   ...
# 25416     IL         3  2019
# 25417     IL         3  2019
# 25418     IL         3  2019
# 25419     IL         3  2019
# 25420     IL         3  2019
# 25421     IL         3  2019
# 25422     IL         3  2019
# 25423     IL         3  2019
# 25424     IL         3  2019
# 25425     IL         3  2019
# 25426     IL         3  2019
# 25427     IL         3  2019
# 25428     IL         3  2019
# 25429     IL         3  2019
# 25430     IL         3  2019
# 25431     IL         3  2019
# 25432     IL         3  2019
# 25433     IL         3  2019
# 25434     IL         3  2019
# 25435     IL         3  2019
# 25436     IL         3  2019
# 25437     IL         3  2019
# 25438     IL         3  2019
# 25439     IL         3  2019
# 25440     IL         3  2019
# 25441     IL         3  2019
# 25442     IL         3  2019
# 25443     IL         3  2019
# 25444     IL         3  2019
# 25445     IL         3  2019
#
# [1058 rows x 37 columns]

# %%
# Return 3 years of Illinois data (04/2016 to 04/2019)

il_df2 = il_df[(il_df['entry_date'] >= '2016-04-01') & (il_df['entry_date'] <= '2019-04-01')]

# %%
# create a new target column:  if the DOM_mm is above the median set equal to 1, otherwise set to 0

dom = inventory_df['daysonmarket_mm']
dom_il = il_df['daysonmarket_mm']

# %%
il_mean = dom_il.mean()

# %%
il_median = dom_il.median()
il_median
# Out:
# 0.0321

# %%
# y_median - threshold is the median value of the DOM m/m
il_df.loc[il_df['daysonmarket_mm'] < il_median, 'y_median'] = 1 # property spending less time on market means higher demand
il_df.loc[il_df['daysonmarket_mm'] >= il_median, 'y_median'] = 0 # property spending more time on market means lower demand

# %%
# y_mean - threshold is the mean value of the DOM m/m
il_df.loc[il_df['daysonmarket_mm'] < il_mean, 'y_mean'] = 1
il_df.loc[il_df['daysonmarket_mm'] >= il_mean, 'y_mean'] = 0

# %%
il_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 37011 entries, 9887 to 1045306
# Data columns (total 39 columns):
# entry_date                37011 non-null datetime64[ns]
# zipcode                   37011 non-null int64
# city-state                37011 non-null object
# medianlistingprice        37011 non-null float64
# medianlistingprice_mm     37011 non-null float64
# medianlistingprice_yy     37011 non-null float64
# activelistingcount        37011 non-null float64
# activelistingcount_mm     37011 non-null float64
# activelistingcount_yy     37011 non-null float64
# daysonmarket              37011 non-null float64
# daysonmarket_mm           37011 non-null float64
# daysonmarket_yy           37011 non-null float64
# newlistingcount           37011 non-null float64
# newlistingcount_mm        37011 non-null float64
# newlistingcount_yy        37011 non-null float64
# priceincreasecount        37011 non-null float64
# priceincreasecount_mm     37011 non-null float64
# priceincreasecount_yy     37011 non-null float64
# pricedecreasecount        37011 non-null float64
# pricedecreasecount_mm     37011 non-null float64
# pricedecreasecount_yy     37011 non-null float64
# pendinglistingcount       37011 non-null float64
# pendinglistingcount_mm    37011 non-null float64
# pendinglistingcount_yy    37011 non-null float64
# avglistingprice           37011 non-null float64
# avglistingprice_mm        37011 non-null float64
# avglistingprice_yy        37011 non-null float64
# totallistingcount         37011 non-null float64
# totallistingcount_mm      37011 non-null float64
# totallistingcount_yy      37011 non-null float64
# pendingratio              37011 non-null float64
# pendingratio_mm           37011 non-null float64
# pendingratio_yy           37011 non-null float64
# City                      37011 non-null object
# State                     37011 non-null object
# month_no                  37011 non-null int64
# year                      37011 non-null int64
# y_median                  37011 non-null int64
# y_mean                    37011 non-null int64
# dtypes: datetime64[ns](1), float64(30), int64(5), object(3)
# memory usage: 11.3+ MB

# %%
# convert target to integers

il_df['y_median'] = il_df['y_median'].astype(int)
il_df['y_mean'] = il_df['y_mean'].astype(int)
# Out:
# /Users/ronald-daley/anaconda3/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/ronald-daley/anaconda3/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
il_df['y_median'].value_counts()
# Out:
# 0    18508
# 1    18503
# Name: y_median, dtype: int64

# %%
il_df['y_mean'].value_counts()
# Out:
# 0    20517
# 1    16494
# Name: y_mean, dtype: int64

# %% [markdown]
# # Data Exploration

# %%
# Groupby y_median - averages

# %%
y_median_gb = il_df.groupby('y_median').mean()

# %%
y_mean_gb = il_df.groupby('y_mean').mean()

# %%
y_median_gb.columns
# Out:
# Index(['zipcode', 'medianlistingprice', 'medianlistingprice_mm',
#        'medianlistingprice_yy', 'activelistingcount', 'activelistingcount_mm',
#        'activelistingcount_yy', 'daysonmarket', 'daysonmarket_mm',
#        'daysonmarket_yy', 'newlistingcount', 'newlistingcount_mm',
#        'newlistingcount_yy', 'priceincreasecount', 'priceincreasecount_mm',
#        'priceincreasecount_yy', 'pricedecreasecount', 'pricedecreasecount_mm',
#        'pricedecreasecount_yy', 'pendinglistingcount',
#        'pendinglistingcount_mm', 'pendinglistingcount_yy', 'avglistingprice',
#        'avglistingprice_mm', 'avglistingprice_yy', 'totallistingcount',
#        'totallistingcount_mm', 'totallistingcount_yy', 'pendingratio',
#        'pendingratio_mm', 'pendingratio_yy', 'month_no', 'year', 'y_mean'],
#       dtype='object')

# %%
# remove the extra columns
y_median_gb = y_median_gb.drop(columns = ['zipcode', 'month_no','year','y_mean'] )

# %%
# remove the DOM columns 
y_median_gb = y_median_gb.drop(columns = ['daysonmarket_mm', 'daysonmarket_yy','daysonmarket'] )

# %%
y_median_gb
# Out:
#           medianlistingprice  medianlistingprice_mm  medianlistingprice_yy  \
# y_median
# 0              223590.962516               0.001248               0.035637
# 1              213290.906150               0.009565               0.037377
#
#           activelistingcount  activelistingcount_mm  activelistingcount_yy  \
# y_median
# 0                 126.092095              -0.030437              -0.033643
# 1                 128.887018               0.033649              -0.044643
#
#           newlistingcount  newlistingcount_mm  newlistingcount_yy  \
# y_median
# 0               29.984655            0.010060            0.009684
# 1               39.758742            0.182248            0.134297
#
#           priceincreasecount  ...  pendinglistingcount_yy  avglistingprice  \
# y_median                      ...
# 0                   0.500648  ...                0.019472    269326.671818
# 1                   0.639464  ...                0.003870    255142.187429
#
#           avglistingprice_mm  avglistingprice_yy  totallistingcount  \
# y_median
# 0                   0.001818            0.046734         139.839043
# 1                   0.006723            0.048006         144.226315
#
#           totallistingcount_mm  totallistingcount_yy  pendingratio  \
# y_median
# 0                    -0.032384              0.000497      0.118416
# 1                     0.037018             -0.018375      0.129870
#
#           pendingratio_mm  pendingratio_yy
# y_median
# 0               -0.001338         0.021597
# 1                0.005558         0.019762
#
# [2 rows x 27 columns]

# %% [markdown]
# 0 = DOM is equal to or above the median DOM for the market (properties in these markets have a  lower demand)
#
# 1 = DOM is below the median DOM for the market (properties in these markets have a higher demand)

# %%
# check for outliers
il_df.describe()
# Out:
#             zipcode  medianlistingprice  medianlistingprice_mm  \
# count  37011.000000        3.701100e+04           37011.000000
# mean   60995.289644        2.184416e+05               0.005406
# std      846.631423        1.721676e+05               0.064346
# min    60002.000000        1.780000e+04              -0.899100
# 25%    60410.000000        1.100500e+05              -0.020800
# 50%    60634.000000        1.790500e+05               0.000000
# 75%    61603.000000        2.667775e+05               0.026900
# max    62995.000000        2.523050e+06               1.920800
#
#        medianlistingprice_yy  activelistingcount  activelistingcount_mm  \
# count           37011.000000        37011.000000           37011.000000
# mean                0.036507          127.489368               0.001601
# std                 0.107752          101.968085               0.115042
# min                -0.555700            0.000000              -0.550000
# 25%                -0.015800           47.500000              -0.066300
# 50%                 0.018000          101.000000              -0.007200
# 75%                 0.096700          180.000000               0.059150
# max                 1.328900          883.000000               1.294700
#
#        activelistingcount_yy  daysonmarket  daysonmarket_mm  daysonmarket_yy  \
# count           37011.000000  37011.000000     37011.000000     37011.000000
# mean               -0.039143     80.728175         0.012861        -0.056816
# std                 0.172655     33.767731         0.179506         0.188196
# min                -0.645200     14.000000        -0.885900        -0.822800
# 25%                -0.148900     57.000000        -0.078900        -0.175600
# 50%                -0.020700     74.000000         0.032100        -0.046100
# 75%                 0.035950     96.500000         0.122500         0.028300
# max                 0.931800    380.000000         1.505100         1.035500
#
#        ...  totallistingcount  totallistingcount_mm  totallistingcount_yy  \
# count  ...       37011.000000          37011.000000          37011.000000
# mean   ...         142.032382              0.002312             -0.008938
# std    ...         113.100345              0.104095              0.220309
# min    ...           0.000000             -0.552600             -1.000000
# 25%    ...          52.500000             -0.062900             -0.144100
# 50%    ...         112.500000             -0.006300             -0.031300
# 75%    ...         202.000000              0.058800              0.096800
# max    ...         963.500000              1.615400              4.153800
#
#        pendingratio  pendingratio_mm  pendingratio_yy      month_no  \
# count  37011.000000     37011.000000     37011.000000  37011.000000
# mean       0.124142         0.002110         0.020680      6.528573
# std        0.183140         0.085221         0.243867      3.495705
# min        0.000000        -1.497300        -2.091400      1.000000
# 25%        0.000000        -0.011600        -0.022900      3.000000
# 50%        0.061300         0.000000         0.000000      7.000000
# 75%        0.157350         0.014100         0.041100     10.000000
# max        2.333300         1.533300         2.333300     12.000000
#
#                year      y_median        y_mean
# count  37011.000000  37011.000000  37011.000000
# mean    2015.915295      0.499932      0.445651
# std        1.729767      0.500007      0.497044
# min     2013.000000      0.000000      0.000000
# 25%     2014.000000      0.000000      0.000000
# 50%     2016.000000      0.000000      0.000000
# 75%     2017.000000      1.000000      1.000000
# max     2019.000000      1.000000      1.000000
#
# [8 rows x 35 columns]

# %%
# because all of the other features are continuous, I cannot do any other groupby, unless I do further feature engineering

# %% [markdown]
# # Data Visualization

# %%
# show plots in the notebook
# %matplotlib inline

# %%
# Pairplot

# %%
sns.pairplot(il_df)
# Out:
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x118d31158> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/anaconda3/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in post_execute()
#     107             def post_execute():
#     108                 if matplotlib.is_interactive():
# --> 109                     draw_all()
#     110
#     111             # IPython >= 2
#
# ~/anaconda3/anaconda3/lib/python3.7/site-packages/matplotlib/_pylab_helpers.py in draw_all(cls, force)
#     126         for f_mgr in cls.get_all_fig_managers():
#     127             if force or f_mgr.canvas.figure.stale:
# --> 128                 f_mgr.canvas.draw_idle()
#     129
#     130 atexit.register(Gcf.destroy_all)
#
# ~/anaconda3/anaconda3/lib/python3.7/site-packages/matplotlib/backend_bases.py in draw_idle(self, *args, **kwargs)
#    1905         if not self._is_idle_drawing:
#    1906             with self._idle_draw_cntx():
# -> 1907                 self.draw(*args, **kwargs)
#    1908
#    1909     def draw_cursor(self, event):
#
# ~/anaconda3/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     386         self.renderer = self.get_renderer(cleared=True)
#     387         with RendererAgg.lock:
# --> 388             self.figure.draw(self.renderer)
#     389             # A GUI class may be need to update a window using this draw, so
#     390             # don't forget to call the superclass.
#
# ~/anaconda3/anaconda3/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~/anaconda3/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1707             self.patch.draw(renderer)
#    1708             mimage._draw_list_compositing_images(
# -> 1709                 renderer, self, artists, self.suppressComposite)
#    1710
#    1711             renderer.close_group('figure')
#
# ~/anaconda3/anaconda3/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# ~/anaconda3/anaconda3/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~/anaconda3/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2603                 artists.remove(spine)
#    2604
# -> 2605         self._update_title_position(renderer)
#    2606
#    2607         if not self.axison or inframe:
#
# ~/anaconda3/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in _update_title_position(self, renderer)
#    2545                     if (ax.xaxis.get_label_position() == 'top' or
#    2546                             ax.xaxis.get_ticks_position() in choices):
# -> 2547                         bb = ax.xaxis.get_tightbbox(renderer)
#    2548                     else:
#    2549                         bb = ax.get_window_extent(renderer)
#
# ~/anaconda3/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py in get_tightbbox(self, renderer)
#    1161             return
#    1162
# -> 1163         ticks_to_draw = self._update_ticks()
#    1164
#    1165         self._update_label_position(renderer)
#
# ~/anaconda3/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py in _update_ticks(self)
#    1078         the axes.  Return the list of ticks that will be drawn.
#    1079         """
# -> 1080         major_locs = self.get_majorticklocs()
#    1081         major_labels = self.major.formatter.format_ticks(major_locs)
#    1082         major_ticks = self.get_major_ticks(len(major_locs))
#
# ~/anaconda3/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py in get_majorticklocs(self)
#    1323     def get_majorticklocs(self):
#    1324         """Get the array of major tick locations in data coordinates."""
# -> 1325         return self.major.locator()
#    1326
#    1327     def get_minorticklocs(self):
#
# ~/anaconda3/anaconda3/lib/python3.7/site-packages/matplotlib/ticker.py in __call__(self)
#    2076     def __call__(self):
#    2077         vmin, vmax = self.axis.get_view_interval()
# -> 2078         return self.tick_values(vmin, vmax)
#    2079
#    2080     def tick_values(self, vmin, vmax):
#
# ~/anaconda3/anaconda3/lib/python3.7/site-packages/matplotlib/ticker.py in tick_values(self, vmin, vmax)
#    2084         vmin, vmax = mtransforms.nonsingular(
#    2085             vmin, vmax, expander=1e-13, tiny=1e-14)
# -> 2086         locs = self._raw_ticks(vmin, vmax)
#    2087
#    2088         prune = self._prune
#
# ~/anaconda3/anaconda3/lib/python3.7/site-packages/matplotlib/ticker.py in _raw_ticks(self, vmin, vmax)
#    2023         if self._nbins == 'auto':
#    2024             if self.axis is not None:
# -> 2025                 nbins = np.clip(self.axis.get_tick_space(),
#    2026                                 max(1, self._min_n_ticks - 1), 9)
#    2027             else:
#
# ~/anaconda3/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py in get_tick_space(self)
#    2173         ends = self.axes.transAxes.transform([[0, 0], [1, 0]])
#    2174         length = ((ends[1][0] - ends[0][0]) / self.axes.figure.dpi) * 72
# -> 2175         tick = self._get_tick(True)
#    2176         # There is a heuristic here that the aspect ratio of tick text
#    2177         # is no more than 3:1
#
# ~/anaconda3/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py in _get_tick(self, major)
#    1904         else:
#    1905             tick_kw = self._minor_tick_kw
# -> 1906         return XTick(self.axes, 0, '', major=major, **tick_kw)
#    1907
#    1908     def _get_label(self):
#
# ~/anaconda3/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major, labelrotation, grid_color, grid_linestyle, grid_linewidth, grid_alpha, **kw)
#     157
#     158         self.tick1line = self._get_tick1line()
# --> 159         self.tick2line = self._get_tick2line()
#     160         self.gridline = self._get_gridline()
#     161         self.label1 = self._get_text1()
#
# ~/anaconda3/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py in _get_tick2line(self)
#     476                           markersize=self._size,
#     477                           markeredgewidth=self._width,
# --> 478                           zorder=self._zorder)
#     479
#     480         l.set_transform(self.axes.get_xaxis_transform(which='tick2'))
#
# ~/anaconda3/anaconda3/lib/python3.7/site-packages/matplotlib/lines.py in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     409
#     410         self._xorig = np.asarray([])
# --> 411         self._yorig = np.asarray([])
#     412         self._invalidx = True
#     413         self._invalidy = True
#
# ~/anaconda3/anaconda3/lib/python3.7/site-packages/numpy/core/numeric.py in asarray(a, dtype, order)
#     536
#     537     """
# --> 538     return array(a, dtype, copy=False, order=order)
#     539
#     540
#
# KeyboardInterrupt:
# Error in callback <function flush_figures at 0x118f911e0> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/anaconda3/anaconda3/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py in flush_figures()
#     115         # ignore the tracking, just draw and close all figures
#     116         try:
# --> 117             return show(True)
#     118         except Exception as e:
#     119             # safely show traceback if in IPython, else raise
#
# ~/anaconda3/anaconda3/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      37             display(
#      38                 figure_manager.canvas.figure,
# ---> 39                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      40             )
#      41     finally:
#
# ~/anaconda3/anaconda3/lib/python3.7/site-packages/IPython/core/display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     304             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     305         else:
# --> 306             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     307             if not format_dict:
#     308                 # nothing to display (e.g. _ipython_display_ took over)
#
# ~/anaconda3/anaconda3/lib/python3.7/site-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# </Users/ronald-daley/anaconda3/anaconda3/lib/python3.7/site-packages/decorator.py:decorator-gen-9> in __call__(self, obj)
#
# ~/anaconda3/anaconda3/lib/python3.7/site-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# ~/anaconda3/anaconda3/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/anaconda3/anaconda3/lib/python3.7/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     242
#     243     if 'png' in formats:
# --> 244         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     245     if 'retina' in formats or 'png2x' in formats:
#     246         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~/anaconda3/anaconda3/lib/python3.7/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     126
#     127     bytes_io = BytesIO()
# --> 128     fig.canvas.print_figure(bytes_io, **kw)
#     129     data = bytes_io.getvalue()
#     130     if fmt == 'svg':
#
# ~/anaconda3/anaconda3/lib/python3.7/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2054                         orientation=orientation,
#    2055                         dryrun=True,
# -> 2056                         **kwargs)
#    2057                     renderer = self.figure._cachedRenderer
#    2058                     bbox_artists = kwargs.pop("bbox_extra_artists", None)
#
# ~/anaconda3/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args, **kwargs)
#     525
#     526         else:
# --> 527             FigureCanvasAgg.draw(self)
#     528             renderer = self.get_renderer()
#     529             with cbook._setattr_cm(renderer, dpi=self.figure.dpi), \
#
# ~/anaconda3/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     386         self.renderer = self.get_renderer(cleared=True)
#     387         with RendererAgg.lock:
# --> 388             self.figure.draw(self.renderer)
#     389             # A GUI class may be need to update a window using this draw, so
#     390             # don't forget to call the superclass.
#
# ~/anaconda3/anaconda3/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~/anaconda3/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1707             self.patch.draw(renderer)
#    1708             mimage._draw_list_compositing_images(
# -> 1709                 renderer, self, artists, self.suppressComposite)
#    1710
#    1711             renderer.close_group('figure')
#
# ~/anaconda3/anaconda3/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# ~/anaconda3/anaconda3/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~/anaconda3/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2643             renderer.stop_rasterizing()
#    2644
# -> 2645         mimage._draw_list_compositing_images(renderer, self, artists)
#    2646
#    2647         renderer.close_group('axes')
#
# ~/anaconda3/anaconda3/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# ~/anaconda3/anaconda3/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~/anaconda3/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py in draw(self, renderer, *args, **kwargs)
#    1207
#    1208         for tick in ticks_to_draw:
# -> 1209             tick.draw(renderer)
#    1210
#    1211         # scale up the axis label box to also find the neighbors, not
#
# ~/anaconda3/anaconda3/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~/anaconda3/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py in draw(self, renderer)
#     295         for artist in [self.gridline, self.tick1line, self.tick2line,
#     296                        self.label1, self.label2]:
# --> 297             artist.draw(renderer)
#     298         renderer.close_group(self.__name__)
#     299         self.stale = False
#
# ~/anaconda3/anaconda3/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~/anaconda3/anaconda3/lib/python3.7/site-packages/matplotlib/lines.py in draw(self, renderer)
#     867                 renderer.draw_markers(gc, marker_path, marker_trans,
#     868                                       subsampled, affine.frozen(),
# --> 869                                       fc_rgba)
#     870
#     871                 alt_marker_path = marker.get_alt_path()
#
# KeyboardInterrupt:

# %%
# bar plot with y-median and zipcode in the x-axis and values in y-axis

# %%
il_df.head()
# Out:
#      entry_date  zipcode             city-state  medianlistingprice  \
# 9887 2019-04-01    60002            Antioch, IL           250000.00
# 9888 2019-04-01    60004  Arlington Heights, IL           349956.25
# 9889 2019-04-01    60005  Arlington Heights, IL           355725.00
# 9890 2019-04-01    60007  Elk Grove Village, IL           299950.00
# 9891 2019-04-01    60008    Rolling Meadows, IL           249950.00
#
#       medianlistingprice_mm  medianlistingprice_yy  activelistingcount  \
# 9887                -0.0198                 0.0038               186.0
# 9888                 0.0000                -0.0669               407.0
# 9889                 0.0047                -0.0489               232.5
# 9890                 0.0166                 0.0909               199.5
# 9891                 0.0869                 0.0870               142.0
#
#       activelistingcount_mm  activelistingcount_yy  daysonmarket  ...  \
# 9887                 0.1481                -0.1878         44.75  ...
# 9888                 0.1274                 0.0970         38.00  ...
# 9889                 0.2109                 0.0764         35.50  ...
# 9890                 0.2547                 0.2627         37.25  ...
# 9891                 0.1545                 0.0290         38.25  ...
#
#       totallistingcount_yy  pendingratio  pendingratio_mm  pendingratio_yy  \
# 9887               -0.2149        0.0215          -0.0032          -0.0353
# 9888                0.0959        0.0528           0.0030          -0.0011
# 9889                0.1121        0.0667          -0.0063           0.0343
# 9890                0.2349        0.0276          -0.0102          -0.0231
# 9891                0.0385        0.0458          -0.0111           0.0095
#
#                    City  State  month_no  year  y_median  y_mean
# 9887            Antioch     IL         4  2019         1       0
# 9888  Arlington Heights     IL         4  2019         1       1
# 9889  Arlington Heights     IL         4  2019         1       1
# 9890  Elk Grove Village     IL         4  2019         0       0
# 9891    Rolling Meadows     IL         4  2019         1       1
#
# [5 rows x 39 columns]

# %%
# Groupby zipcode and year to find mean value per column
zip_year_gb_mean = il_df.groupby(['zipcode', 'year']).mean()
zip_year_gb_mean.head(13)
# Out:
#               medianlistingprice  medianlistingprice_mm  \
# zipcode year
# 60002   2013       191858.333333               0.000183
#         2014       207231.250000               0.013567
#         2015       220687.458333              -0.007708
#         2016       221297.708333               0.004492
#         2017       237798.333333               0.007975
#         2018       243770.166667               0.003650
#         2019       252492.500000               0.010725
# 60004   2013       320683.333333               0.002867
#         2014       348356.208333               0.009933
#         2015       356200.000000              -0.004267
#         2016       367745.812500               0.004825
#         2017       378502.083333               0.002667
#         2018       366471.875000              -0.005592
#
#               medianlistingprice_yy  activelistingcount  \
# zipcode year
# 60002   2013               0.009667          290.333333
#         2014               0.052100          250.708333
#         2015               0.076833          240.291667
#         2016               0.008950          215.166667
#         2017               0.074442          200.041667
#         2018               0.019950          210.041667
#         2019               0.047650          153.625000
# 60004   2013               0.000000          273.500000
#         2014               0.027967          256.458333
#         2015               0.023642          247.541667
#         2016               0.031058          324.541667
#         2017               0.029775          328.125000
#         2018              -0.031458          343.083333
#
#               activelistingcount_mm  activelistingcount_yy  daysonmarket  \
# zipcode year
# 60002   2013              -0.026900               0.179900     96.375000
#         2014              -0.020417              -0.035042     90.687500
#         2015               0.025217               0.029208     81.500000
#         2016              -0.015292              -0.080925     75.437500
#         2017               0.008133              -0.069333     64.187500
#         2018              -0.003825               0.008425     62.062500
#         2019               0.049025              -0.212725     65.125000
# 60004   2013              -0.092550              -0.185750     66.958333
#         2014               0.006500              -0.087017     56.687500
#         2015               0.037542               0.002850     51.770833
#         2016               0.001117              -0.005333     52.854167
#         2017               0.013208               0.015058     48.791667
#         2018               0.016608               0.045600     45.708333
#
#               daysonmarket_mm  daysonmarket_yy  newlistingcount  ...  \
# zipcode year                                                     ...
# 60002   2013         0.088867        -0.092167        47.666667  ...
#         2014        -0.008475        -0.113750        56.166667  ...
#         2015         0.019475        -0.014258        53.333333  ...
#         2016         0.001758        -0.073692        49.166667  ...
#         2017        -0.007350        -0.144775        55.666667  ...
#         2018        -0.000150         0.007433        60.000000  ...
#         2019        -0.052100        -0.017175        52.500000  ...
# 60004   2013         0.083600        -0.096950        65.666667  ...
#         2014         0.002758        -0.159525        89.000000  ...
#         2015         0.010250        -0.039133        97.333333  ...
#         2016         0.011833        -0.004325       107.333333  ...
#         2017         0.003742        -0.075283       119.500000  ...
#         2018         0.022683        -0.061583       135.333333  ...
#
#               avglistingprice_yy  totallistingcount  totallistingcount_mm  \
# zipcode year
# 60002   2013           -0.009583         290.333333             -0.026900
#         2014            0.069325         269.958333             -0.001850
#         2015            0.081233         284.666667              0.004658
#         2016           -0.004608         227.750000             -0.013000
#         2017            0.076950         214.083333              0.007317
#         2018            0.052767         219.208333             -0.006642
#         2019            0.027600         157.750000              0.046675
# 60004   2013            0.258350         273.500000             -0.092550
#         2014            0.170700         284.416667              0.031842
#         2015            0.065175         333.500000              0.004533
#         2016            0.012825         342.916667              0.003050
#         2017            0.032883         345.541667              0.010883
#         2018           -0.006100         355.916667              0.015475
#
#               totallistingcount_yy  pendingratio  pendingratio_mm  \
# zipcode year
# 60002   2013              0.179900      0.000000         0.000000
#         2014              0.033592      0.092717         0.024442
#         2015              0.049050      0.196958        -0.021483
#         2016             -0.186850      0.059325         0.003208
#         2017             -0.059900      0.071133        -0.001058
#         2018              0.031117      0.044250        -0.002542
#         2019             -0.242225      0.027375        -0.002400
# 60004   2013             -0.185750      0.000000         0.000000
#         2014              0.012608      0.127750         0.036958
#         2015              0.196575      0.415600        -0.033475
#         2016              0.026667      0.056775         0.001975
#         2017              0.010917      0.053125        -0.002533
#         2018              0.030233      0.037642        -0.001175
#
#               pendingratio_yy  month_no  y_median    y_mean
# zipcode year
# 60002   2013         0.000000       9.5  0.166667  0.166667
#         2014         0.092717       6.5  0.583333  0.416667
#         2015         0.104258       6.5  0.333333  0.250000
#         2016        -0.137650       6.5  0.333333  0.333333
#         2017         0.011833       6.5  0.416667  0.416667
#         2018        -0.026908       6.5  0.333333  0.333333
#         2019        -0.040425       2.5  0.500000  0.250000
# 60004   2013         0.000000       9.5  0.333333  0.166667
#         2014         0.127750       6.5  0.416667  0.416667
#         2015         0.287850       6.5  0.500000  0.416667
#         2016        -0.358825       6.5  0.333333  0.250000
#         2017        -0.003692       6.5  0.500000  0.500000
#         2018        -0.015458       6.5  0.500000  0.500000
#
# [13 rows x 33 columns]

# %%
# Groupby zip and year to find median value per column

zip_year_gb_median = il_df.groupby(['zipcode', 'year']).median()
zip_year_gb_median.head(7)
# Out:
#               medianlistingprice  medianlistingprice_mm  \
# zipcode year
# 60002   2013            192287.5               -0.00120
#         2014            209500.0                0.00670
#         2015            222350.0                0.00620
#         2016            223250.0                0.00490
#         2017            240747.5                0.01265
#         2018            244912.5                0.00185
#         2019            252460.0                0.00150
#
#               medianlistingprice_yy  activelistingcount  \
# zipcode year
# 60002   2013                0.00440              300.00
#         2014                0.05140              240.25
#         2015                0.10190              245.50
#         2016                0.00600              219.25
#         2017                0.07090              199.25
#         2018                0.01005              217.00
#         2019                0.04480              149.75
#
#               activelistingcount_mm  activelistingcount_yy  daysonmarket  \
# zipcode year
# 60002   2013               -0.03050                0.19115        93.125
#         2014               -0.01475                0.03245        83.500
#         2015                0.02145                0.00000        83.500
#         2016               -0.01050               -0.08465        69.500
#         2017                0.01175               -0.05395        57.875
#         2018               -0.01310                0.00525        59.750
#         2019                0.04315               -0.22235        63.250
#
#               daysonmarket_mm  daysonmarket_yy  newlistingcount  ...  \
# zipcode year                                                     ...
# 60002   2013          0.13710         -0.04520             49.0  ...
#         2014          0.02685         -0.11405             55.0  ...
#         2015          0.04615          0.03615             51.0  ...
#         2016          0.04610         -0.11425             50.0  ...
#         2017          0.04375         -0.14925             60.0  ...
#         2018          0.04240          0.02870             61.0  ...
#         2019          0.05895         -0.05595             57.0  ...
#
#               avglistingprice_yy  totallistingcount  totallistingcount_mm  \
# zipcode year
# 60002   2013            -0.00415              300.0              -0.03050
#         2014             0.05265              278.0              -0.01475
#         2015             0.09430              287.5              -0.02375
#         2016             0.00390              229.0              -0.01675
#         2017             0.08880              214.0              -0.00200
#         2018             0.04845              225.0              -0.01560
#         2019             0.03100              154.5               0.03385
#
#               totallistingcount_yy  pendingratio  pendingratio_mm  \
# zipcode year
# 60002   2013               0.19115       0.00000           0.0000
#         2014               0.03245       0.00000           0.0000
#         2015               0.05225       0.26735           0.0021
#         2016              -0.20325       0.05955           0.0002
#         2017              -0.03270       0.06405           0.0004
#         2018               0.02595       0.04420          -0.0017
#         2019              -0.24815       0.02400          -0.0009
#
#               pendingratio_yy  month_no  y_median  y_mean
# zipcode year
# 60002   2013          0.00000       9.5       0.0     0.0
#         2014          0.00000       6.5       1.0     0.0
#         2015          0.26735       6.5       0.0     0.0
#         2016         -0.19925       6.5       0.0     0.0
#         2017          0.00905       6.5       0.0     0.0
#         2018         -0.03130       6.5       0.0     0.0
#         2019         -0.03510       2.5       0.5     0.0
#
# [7 rows x 33 columns]

# %%
# Groupby year to find median value per column
year_gb_median = il_df.groupby([ 'year']).median()
year_gb_median
# Out:
#       zipcode  medianlistingprice  medianlistingprice_mm  \
# year
# 2013  60634.0            149950.0                0.00000
# 2014  60635.0            159950.0                0.00040
# 2015  60634.0            172500.0                0.00000
# 2016  60634.0            175500.0                0.00030
# 2017  60634.0            189950.0                0.00020
# 2018  60634.0            199950.0                0.00000
# 2019  60634.0            199950.0                0.00385
#
#       medianlistingprice_yy  activelistingcount  activelistingcount_mm  \
# year
# 2013                0.00760               121.0                -0.0319
# 2014                0.01660               111.0                -0.0029
# 2015                0.01720                97.5                 0.0000
# 2016                0.00310               106.0                -0.0100
# 2017                0.03975                97.5                -0.0075
# 2018                0.01995                92.5                 0.0000
# 2019                0.00000                82.0                 0.0185
#
#       activelistingcount_yy  daysonmarket  daysonmarket_mm  daysonmarket_yy  \
# year
# 2013               -0.08330         86.50          0.05140         -0.11220
# 2014               -0.01610         83.50          0.02820         -0.05425
# 2015                0.00000         76.25          0.03740         -0.04210
# 2016                0.00000         74.00          0.03175          0.00000
# 2017               -0.08155         66.50          0.03370         -0.08080
# 2018               -0.03570         62.50          0.03330         -0.04730
# 2019                0.00000         70.50         -0.03775          0.00000
#
#       ...  avglistingprice_yy  totallistingcount  totallistingcount_mm  \
# year  ...
# 2013  ...             0.04095             121.00              -0.03190
# 2014  ...             0.06535             121.00               0.00405
# 2015  ...             0.04370             123.00              -0.00790
# 2016  ...             0.02575             117.00              -0.01025
# 2017  ...             0.04495             108.00              -0.00860
# 2018  ...             0.02660             102.00              -0.00155
# 2019  ...             0.01360              92.75               0.03030
#
#       totallistingcount_yy  pendingratio  pendingratio_mm  pendingratio_yy  \
# year
# 2013              -0.08770       0.00000           0.0000           0.0000
# 2014               0.01350       0.00000           0.0000           0.0000
# 2015               0.03720       0.13860           0.0000           0.0947
# 2016              -0.04965       0.07870           0.0000          -0.0230
# 2017              -0.08810       0.07890           0.0000          -0.0015
# 2018              -0.04550       0.07605           0.0000          -0.0023
# 2019               0.00810       0.07745           0.0036           0.0000
#
#       month_no  y_median  y_mean
# year
# 2013       9.0       0.0     0.0
# 2014       6.5       1.0     0.0
# 2015       7.0       0.0     0.0
# 2016       6.5       1.0     0.0
# 2017       6.5       0.0     0.0
# 2018       6.5       0.0     0.0
# 2019       2.5       1.0     1.0
#
# [7 rows x 34 columns]

# %%
# Groupby year to find mean value per column
year_gb_mean = il_df.groupby([ 'year']).mean()
year_gb_mean
# Out:
#            zipcode  medianlistingprice  medianlistingprice_mm  \
# year
# 2013  60995.678864       193297.169953               0.000367
# 2014  60996.007576       203897.381944               0.008428
# 2015  60995.268558       213991.946887               0.002291
# 2016  60995.022684       217749.079080               0.005833
# 2017  60995.022684       228752.775638               0.006769
# 2018  60995.022684       234809.788595               0.003565
# 2019  60995.022684       235043.532727               0.013404
#
#       medianlistingprice_yy  activelistingcount  activelistingcount_mm  \
# year
# 2013               0.034057          145.996688              -0.028462
# 2014               0.044253          136.161379              -0.007076
# 2015               0.037031          123.003783               0.017435
# 2016               0.025467          133.527804              -0.003373
# 2017               0.049343          123.154773              -0.002116
# 2018               0.034337          118.985744               0.007227
# 2019               0.016535          107.646267               0.034338
#
#       activelistingcount_yy  daysonmarket  daysonmarket_mm  daysonmarket_yy  \
# year
# 2013              -0.075177     90.632965         0.047128        -0.108760
# 2014              -0.033382     90.314867         0.010434        -0.058340
# 2015              -0.033511     83.696533         0.015358        -0.056167
# 2016              -0.009083     80.913398         0.012279        -0.025756
# 2017              -0.077560     73.879608         0.015087        -0.078353
# 2018              -0.037454     70.636578         0.017591        -0.052321
# 2019               0.000713     78.547968        -0.057810        -0.018435
#
#       ...  avglistingprice_yy  totallistingcount  totallistingcount_mm  \
# year  ...
# 2013  ...            0.043022         145.996688             -0.028462
# 2014  ...            0.069230         147.273990              0.009716
# 2015  ...            0.050254         154.354689              0.001773
# 2016  ...            0.032913         147.161468             -0.003025
# 2017  ...            0.053856         135.883349             -0.002465
# 2018  ...            0.037027         131.205892              0.007210
# 2019  ...            0.034717         118.988185              0.043514
#
#       totallistingcount_yy  pendingratio  pendingratio_mm  pendingratio_yy  \
# year
# 2013             -0.054833      0.000000         0.000000         0.000000
# 2014              0.035038      0.087363         0.022937         0.087363
# 2015              0.055153      0.262717        -0.015354         0.175268
# 2016             -0.039067      0.105541         0.000693        -0.157125
# 2017             -0.063573      0.110776        -0.000429         0.005235
# 2018             -0.025150      0.115955         0.000402         0.005178
# 2019              0.038893      0.125188         0.012264         0.014698
#
#       month_no  y_median    y_mean
# year
# 2013  9.499369  0.432808  0.366877
# 2014  6.500000  0.511837  0.451231
# 2015  6.502128  0.484791  0.425374
# 2016  6.500000  0.500473  0.445810
# 2017  6.500000  0.496062  0.446597
# 2018  6.500000  0.496377  0.448330
# 2019  2.500000  0.630907  0.596408
#
# [7 rows x 34 columns]

# %% [markdown]
# # Export Data

# %%
df.to_csv(file_name, sep='\t')

# %%
# Export Illinois Data

il_df.to_excel('il_data3.xlsx', index=False, header = True)
